# %%
##################### Phase 2: Data Cleaning & Preprocessing #####################

# List of the only columns we actually care about
columns_to_keep = [
    'Name',          # Run ID
    'Well',          # Plate position
    'Target',        # The channel (FAM, ROX, HEX, CY5)
    'Cq (∆R)',       # Cycle Threshold (Viral Load)
    'Final Call (∆R)', # Positive or Negative
    'Source_File'    # Batch tracker
]

# Create a clean, lightweight version of the dataset
clean_df = combined_df[columns_to_keep].copy()

# Rename the columns so they are clean and professional for Kaggle
clean_df.rename(columns={
    'Name': 'Run_ID',
    'Cq (∆R)': 'Cq_Value',
    'Final Call (∆R)': 'Final_Call'
}, inplace=True)

# Preview the beautiful, clean dataset
display(clean_df.head())
